# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\Prashant\_Companies by Bleezur.xlsx")
data
# Out:
#     Unnamed: 0                                               Name  \
# 0            1                                           Appvance
# 1            2                                                RT²
# 2            3                                     OperaSolutions
# 3            4                                           GoCanvas
# 4            5                                      Veevo Systems
# 5            6                                          Teamworks
# 6            7                                  Solutions by Text
# 7            8                                        GlossGenius
# 8            9                                    Sigma Computing
# 9           10                  Research Innovations Incorporated
# 10          11                                        Sofar Ocean
# 11          12  Social Media Marketing Specialist,Manager of I...
# 12          13                                        Advantasure
# ...

# %%
data.to_json('data.json', orient='records')
